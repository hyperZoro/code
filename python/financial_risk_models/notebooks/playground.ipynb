# %% [markdown]
# # Financial Risk Model Playground
# Use this notebook to interactively inspect data, train models, and compare performance.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from utils.data_loader import download_data, calculate_log_returns
from models.traditional import TraditionalModels

# %matplotlib inline

# %% [markdown]
# ## 1. Load Data

# %%
tickers = ['SPY', 'EURUSD=X']
data = download_data(tickers, '2015-01-01', '2023-01-01')
returns = calculate_log_returns(data)
returns.plot(figsize=(12, 6), title='Log Returns')

# %% [markdown]
# ## 2. GARCH Model (Traditional)

# %%
spy_ret = returns['SPY'] * 100 # Scaling helps convergence
res = TraditionalModels.fit_garch(spy_ret)
print(res.summary())
res.plot()
