# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource
import pandas as pd

# Step 1: Prepare data for visualization
# Create a DataFrame for actual and predicted values
predicted_values = predictions.numpy().flatten()
actual_values = weekly_log_return.values[seq_length:]  # Align with predictions

# Create a DataFrame
visualization_df = pd.DataFrame({
    'Date': weekly_log_return.index[seq_length:],
    'Actual': actual_values,
    'Predicted': predicted_values
})

# Step 2: Use Bokeh to create a plot
output_notebook()  # Use this if you're in a Jupyter Notebook

# Create a ColumnDataSource
source = ColumnDataSource(visualization_df)

# Create a figure
p = figure(title="LSTM Model Predictions vs Actual Log Returns",
           x_axis_label='Date', y_axis_label='Log Return',
           x_axis_type='datetime', width=800, height=400)

# Add actual and predicted lines
p.line('Date', 'Actual', source=source, legend_label='Actual Log Return', line_color='blue', line_width=2)
p.line('Date', 'Predicted', source=source, legend_label='Predicted Log Return', line_color='orange', line_width=2)

# Customize the legend
p.legend.location = "top_left"
p.legend.click_policy = "hide"

# Show the plot
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d20e1b29-e614-4f9a-a819-6043bb921be3">Loading BokehJS ...</span>
#     </div>
#   <div id="ad8f0744-a77a-4558-afcc-f29e6e9c029e" data-root-id="p1004" style="display: contents;"></div>
